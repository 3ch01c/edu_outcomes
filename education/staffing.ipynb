# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/tabn213.10_pct_dist.csv", thousands=',')

# %%
df
# Out:
#           Date  Librarians  Officials and administrators  \
# 0     1949-50          NaN                           1.8
# 1     1959-60          0.8                           1.4
# 2     1969-70          1.3                           1.0
# 3    Fall 1980         1.2                           1.4
# 4   Fall 1990          1.1                           NaN
# 5   Fall 2000          1.0                           1.0
# 6    Fall 2002         0.9                           1.1
# 7    Fall 2003         0.9                           1.1
# 8    Fall 2004         0.9                           1.1
# 9    Fall 2005         0.9                           1.0
# 10   Fall 2006         0.9                           0.9
# 11   Fall 2007         0.9                           1.0
# 12   Fall 2008         0.9                           1.0
# 13   Fall 2009         0.8                           1.0
# 14   Fall 2010         0.8                           1.0
# ...

# %%
df.plot(kind='bar', x='Date', stacked=True, title="Staff employed in public elementary and secondary school systems")
# Out:
# <Axes: title={'center': 'Staff employed in public elementary and secondary school systems'}, xlabel='Date'>
