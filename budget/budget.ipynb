# %%
import pandas as pd
import numpy as np
# %pip install openpyxl
import matplotlib.pyplot as plt
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# read ../data/per_capita_public_spending.csv into pandas dataframe parsing airports column as integers
df = pd.read_csv('../data/per_capita_public_spending.csv', thousands=',')

# %%
# bar plot of per capita public spending by government using df.plot and rotate x-axis labels
df.plot.bar(x='Government', y='Per capita public spending', rot=90, title='Per Capita Public Spending by Government')
# Out:
# <Axes: title={'center': 'Per Capita Public Spending by Government'}, xlabel='Government'>

# %%
df
# Out:
#               Government  Per capita public spending    FY  Population
# 0  Los Alamos County, NM                       11351  2022       18049  \
# 1      Pitkin County, CO                        8011  2021       17800
# 2  City of Oak Ridge, TN                        7005  2021       29356
# 3      Summit County, CO                        4282  2022       32132
# 4             New Mexico                        3633  2022     2100000
# 5      Benton County, WA                        1494  2022      204390
# 6    Anderson County, TN                         825  2022       77310
#
#    FFRDCs  Airports  Ski Areas
# 0       1         1          1
# 1       0         1          4
# 2       1         0          0
# 3       0         1          4
# 4       2        62          7
# 5       1         1          0
# 6       1         0          0

# %%
# write dataframe to csv file
#df.to_csv('../data/per_capita_public_spending.csv', index=False)
