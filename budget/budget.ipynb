# %%
import pandas as pd
import numpy as np
# %pip install openpyxl
import matplotlib.pyplot as plt
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# read LAC Budget 2023.xlsx into pandas dataframe
df = pd.read_excel('../data/LAC Budget 2023.xlsx', sheet_name='Per Capita Public Spending')

# %%
# bar plot of per capita public spending by government using df.plot and rotate x-axis labels
df.plot.bar(x='Government', y='Per capita spending', rot=90, title='Per Capita Public Spending by Government')
# Out:
# <Axes: xlabel='Government'>

# %%
df
# Out:
#               Government  Per capita spending    FY  Population  FFRDCs
# 0  Los Alamos County, NM                11351  2022       18049       1  \
# 1      Pitkin County, CO                 8011  2021       17800       0
# 2  City of Oak Ridge, TN                 7005  2021       29356       1
# 3      Summit County, CO                 4282  2022       32132       0
# 4             New Mexico                 3633  2022     2100000       2
# 5      Benton County, WA                 1494  2022      204390       1
# 6    Anderson County, TN                  825  2022       77310       1
#
#    Airports  Ski Areas
# 0       1.0          1
# 1       1.0          4
# 2       0.0          0
# 3       1.0          4
# 4       NaN          7
# 5       1.0          0
# 6       0.0          0

# %%
# write dataframe to xlsx file
#df.to_excel('../data/LAC Budget 2023.xlsx', sheet_name='Per Capita Public Spending', index=False)
